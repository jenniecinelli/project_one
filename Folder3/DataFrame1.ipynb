# %%
import json
import requests
import numpy as np
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/Users/mohamedismael/Desktop/project_1/project_one/Folder3'

# %%
df1 = pd.read_csv("../Folder2/Final_DeathRate_byState_042021.csv")
df1
# Out:
#    Unnamed: 0  Covid_Death_Rate
# 0         NaN          4.000000
# 1         NaN       2021.000000
# 2       State               NaN
# 3         RMI          0.000000
# 4         FSM          0.000000
# ..        ...               ...
# 58         NJ          2.560801
# 59         MA          2.663615
# 60        NYC          3.507770
# 61         AS               NaN
# 62         PW               NaN
#
# [63 rows x 2 columns]

# %%
df1.rename(columns={"Unnamed: 0": "State", "Covid_Death_Rate":"Cum_Covid_19_Death_Rate"},inplace=True)
df1.drop([0,1,2,3,4,60,62,56],inplace=True)
states = df1["State"]
death_rate_df1 = df1["Cum_Covid_19_Death_Rate"]
x_axis = np.arange(len(df1))
tick_locations = [value+0.4 for value in x_axis]
death_rate_df1.head()
# Out:
# 5    0.521335
# 6    0.554209
# 7    0.864000
# 8    1.020306
# 9    1.071802
# Name: Cum_Covid_19_Death_Rate, dtype: float64

# %%
x_axis = np.arange(0, len(df1))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Covid-19 death rate by State")
plt.xlabel("States")
plt.ylabel("Percentages of deaths")


plt.bar(x_axis, death_rate, facecolor="red", alpha=0.75, align="center")
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, df1 ['State'],color='r', alpha=0.75, align="center")
plt.xticks(tick_locations, df1["State"], rotation="vertical")
plt.title("Covid-19 death rate by State")
plt.xlabel("States")
plt.ylabel("Percentages of deaths")
plt.show()

# %%
df1.Cum_Covid_19_Death_Rate.describe()
# Out:
# count    54.000000
# mean      1.608963
# std       0.440958
# min       0.521335
# 25%       1.353611
# 50%       1.621231
# 75%       1.831226
# max       2.663615
# Name: Cum_Covid_19_Death_Rate, dtype: float64
